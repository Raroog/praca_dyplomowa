# %%
from pathlib import Path
import shutil
from sklearn.model_selection import train_test_split

# %%
data_path = Path("/home/bartek/Kod/PD/praca_dyplomowa/dane/resnet_dane/raw/codescan")

# %%
violet_path = Path("/home/bartek/Kod/PD/praca_dyplomowa/dane/resnet_dane/violet")

# %%
code_images = list(data_path.glob("**/**/**/*.png"))[:5153]

# %%
violet_code_images = list(violet_path.glob("*.png"))[:500]

# %%
print(len(code_images))
print(len(violet_code_images))
# Out:
# 5153
# 500

# %%
all_images = code_images
all_images.extend(violet_code_images)

# %%
print(len(all_images))
# Out:
# 5653

# %%
[path for path in all_images if "violet" not in str(path)]
# Out:
# [PosixPath('/home/bartek/Kod/PD/praca_dyplomowa/dane/resnet_dane/raw/codescan/C/openvenues~libpostal/src~acronyms.c/img.png'),
#  PosixPath('/home/bartek/Kod/PD/praca_dyplomowa/dane/resnet_dane/raw/codescan/C/openvenues~libpostal/src~acronyms.c/bw.png'),
#  PosixPath('/home/bartek/Kod/PD/praca_dyplomowa/dane/resnet_dane/raw/codescan/C/openvenues~libpostal/src~sse2neon.h/img.png'),
#  PosixPath('/home/bartek/Kod/PD/praca_dyplomowa/dane/resnet_dane/raw/codescan/C/openvenues~libpostal/src~sse2neon.h/bw.png'),
#  PosixPath('/home/bartek/Kod/PD/praca_dyplomowa/dane/resnet_dane/raw/codescan/C/openvenues~libpostal/src~crf_context.c/img.png'),
#  PosixPath('/home/bartek/Kod/PD/praca_dyplomowa/dane/resnet_dane/raw/codescan/C/openvenues~libpostal/src~crf_context.c/bw.png'),
#  PosixPath('/home/bartek/Kod/PD/praca_dyplomowa/dane/resnet_dane/raw/codescan/C/openvenues~libpostal/src~vector_math.h/img.png'),
# ...

# %%
code_train, code_val = train_test_split(
    all_images, 
    train_size=0.8, 
    random_state=42
)

# %%
base_dir = Path("/home/bartek/Kod/PD/praca_dyplomowa/dane/resnet_dane/ready")

# %%
for img_path in code_train:
    shutil.copy2(img_path, base_dir / 'train' / 'code' / img_path.name)

for img_path in code_val:
    shutil.copy2(img_path, base_dir / 'val' / 'code' / img_path.name)
